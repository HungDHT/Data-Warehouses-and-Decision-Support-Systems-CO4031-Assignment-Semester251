-- %% [markdown]
-- # [DW_Customer_Segmentation]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DW_Customer_Segmentation]    Script Date: 2 Dec 2025 5:32:49 pm ******/
CREATE DATABASE [DW_Customer_Segmentation]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DW_Customer_Segmentation', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DW_Customer_Segmentation.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DW_Customer_Segmentation_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DW_Customer_Segmentation_log.ldf' , SIZE = 204800KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DW_Customer_Segmentation] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DW_Customer_Segmentation].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ARITHABORT OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET RECOVERY FULL 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET  MULTI_USER 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DW_Customer_Segmentation] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DW_Customer_Segmentation] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DW_Customer_Segmentation', N'ON'
GO
ALTER DATABASE [DW_Customer_Segmentation] SET QUERY_STORE = ON
GO
ALTER DATABASE [DW_Customer_Segmentation] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[DimCustomer]

-- %%
USE [DW_Customer_Segmentation]
GO

-- %%
/****** Object:  Table [dbo].[DimCustomer]    Script Date: 2 Dec 2025 5:32:50 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimCustomer](
	[CustomerKey] [int] IDENTITY(1,1) NOT NULL,
	[PersonID] [int] NULL,
	[CustomerID] [int] NULL,
	[FirstName] [nvarchar](50) NULL,
	[LastName] [nvarchar](50) NULL,
	[FullName] [nvarchar](150) NULL,
	[EmailPromotion] [int] NULL,
	[Gender] [nvarchar](1) NULL,
PRIMARY KEY CLUSTERED 
(
	[CustomerKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimDate]

-- %%
/****** Object:  Table [dbo].[DimDate]    Script Date: 2 Dec 2025 5:32:50 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimDate](
	[DateKey] [int] NOT NULL,
	[FullDate] [date] NULL,
	[Year] [int] NULL,
	[Quarter] [int] NULL,
	[Month] [int] NULL,
	[MonthName] [nvarchar](15) NULL,
	[DayOfMonth] [int] NULL,
	[DayOfWeek] [int] NULL,
	[DayOfWeekName] [nvarchar](15) NULL,
	[IsWeekend] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[DateKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimGeography]

-- %%
/****** Object:  Table [dbo].[DimGeography]    Script Date: 2 Dec 2025 5:32:50 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimGeography](
	[GeographyKey] [int] IDENTITY(1,1) NOT NULL,
	[AddressID] [int] NULL,
	[City] [nvarchar](30) NULL,
	[StateProvinceName] [nvarchar](50) NULL,
	[CountryRegionName] [nvarchar](50) NULL,
	[PostalCode] [nvarchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[GeographyKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProduct]

-- %%
/****** Object:  Table [dbo].[DimProduct]    Script Date: 2 Dec 2025 5:32:50 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProduct](
	[ProductKey] [int] IDENTITY(1,1) NOT NULL,
	[ProductID] [int] NULL,
	[ProductName] [nvarchar](50) NULL,
	[Color] [nvarchar](15) NULL,
	[StandardCost] [money] NULL,
	[ListPrice] [money] NULL,
	[SubCategoryName] [nvarchar](50) NULL,
	[CategoryName] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ProductKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactSales]

-- %%
/****** Object:  Table [dbo].[FactSales]    Script Date: 2 Dec 2025 5:32:50 pm ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactSales](
	[FactSalesKey] [int] IDENTITY(1,1) NOT NULL,
	[ProductKey] [int] NOT NULL,
	[CustomerKey] [int] NOT NULL,
	[GeographyKey] [int] NOT NULL,
	[OrderDateKey] [int] NOT NULL,
	[SalesOrderNumber] [nvarchar](25) NULL,
	[OrderQuantity] [int] NULL,
	[UnitPrice] [money] NULL,
	[TotalLineAmount] [money] NULL,
	[TaxAmt] [money] NULL,
	[Freight] [money] NULL,
	[TotalProductCost] [money] NULL,
	[OrderStatus] [tinyint] NULL,
PRIMARY KEY CLUSTERED 
(
	[FactSalesKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DW_Customer_Segmentation]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DW_Customer_Segmentation] SET  READ_WRITE 
GO
